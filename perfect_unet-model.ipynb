# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/README.md
# /kaggle/input/train.csv
# /kaggle/input/test.csv
# /kaggle/input/images/641.png
# /kaggle/input/images/173.png
# /kaggle/input/images/491.png
# /kaggle/input/images/718.png
# /kaggle/input/images/709.png
# /kaggle/input/images/379.png
# /kaggle/input/images/780.png
# /kaggle/input/images/248.png
# /kaggle/input/images/94.png
# /kaggle/input/images/480.png
# /kaggle/input/images/236.png
# /kaggle/input/images/771.png
# /kaggle/input/images/675.png
# /kaggle/input/images/340.png
# /kaggle/input/images/48.png
# /kaggle/input/images/513.png
# /kaggle/input/images/677.png
# /kaggle/input/images/350.png
# /kaggle/input/images/761.png
# /kaggle/input/images/314.png
# /kaggle/input/images/655.png
# /kaggle/input/images/227.png
# /kaggle/input/images/762.png
# /kaggle/input/images/726.png
# /kaggle/input/images/238.png
# /kaggle/input/images/61.png
# /kaggle/input/images/377.png
# /kaggle/input/images/581.png
# /kaggle/input/images/222.png
# /kaggle/input/images/330.png
# /kaggle/input/images/511.png
# /kaggle/input/images/579.png
# /kaggle/input/images/278.png
# /kaggle/input/images/303.png
# /kaggle/input/images/37.png
# /kaggle/input/images/231.png
# /kaggle/input/images/645.png
# /kaggle/input/images/348.png
# /kaggle/input/images/449.png
# /kaggle/input/images/353.png
# /kaggle/input/images/621.png
# /kaggle/input/images/148.png
# /kaggle/input/images/403.png
# /kaggle/input/images/352.png
# /kaggle/input/images/35.png
# /kaggle/input/images/232.png
# /kaggle/input/images/334.png
# /kaggle/input/images/177.png
# /kaggle/input/images/142.png
# /kaggle/input/images/754.png
# /kaggle/input/images/407.png
# /kaggle/input/images/104.png
# /kaggle/input/images/384.png
# /kaggle/input/images/376.png
# /kaggle/input/images/543.png
# /kaggle/input/images/737.png
# /kaggle/input/images/133.png
# /kaggle/input/images/70.png
# /kaggle/input/images/162.png
# /kaggle/input/images/419.png
# /kaggle/input/images/517.png
# /kaggle/input/images/398.png
# /kaggle/input/images/634.png
# /kaggle/input/images/186.png
# /kaggle/input/images/778.png
# /kaggle/input/images/73.png
# /kaggle/input/images/92.png
# /kaggle/input/images/542.png
# /kaggle/input/images/766.png
# /kaggle/input/images/315.png
# /kaggle/input/images/436.png
# /kaggle/input/images/359.png
# /kaggle/input/images/261.png
# /kaggle/input/images/153.png
# /kaggle/input/images/167.png
# /kaggle/input/images/628.png
# /kaggle/input/images/506.png
# /kaggle/input/images/441.png
# /kaggle/input/images/562.png
# /kaggle/input/images/681.png
# /kaggle/input/images/204.png
# /kaggle/input/images/646.png
# /kaggle/input/images/75.png
# /kaggle/input/images/296.png
# /kaggle/input/images/744.png
# /kaggle/input/images/538.png
# /kaggle/input/images/651.png
# /kaggle/input/images/270.png
# /kaggle/input/images/89.png
# /kaggle/input/images/385.png
# /kaggle/input/images/768.png
# /kaggle/input/images/338.png
# /kaggle/input/images/333.png
# /kaggle/input/images/164.png
# /kaggle/input/images/752.png
# /kaggle/input/images/550.png
# /kaggle/input/images/521.png
# /kaggle/input/images/11.png
# /kaggle/input/images/615.png
# /kaggle/input/images/416.png
# /kaggle/input/images/605.png
# /kaggle/input/images/707.png
# /kaggle/input/images/351.png
# /kaggle/input/images/213.png
# /kaggle/input/images/411.png
# /kaggle/input/images/505.png
# /kaggle/input/images/114.png
# /kaggle/input/images/302.png
# /kaggle/input/images/185.png
# /kaggle/input/images/240.png
# /kaggle/input/images/317.png
# /kaggle/input/images/281.png
# /kaggle/input/images/344.png
# /kaggle/input/images/457.png
# /kaggle/input/images/493.png
# /kaggle/input/images/759.png
# /kaggle/input/images/362.png
# /kaggle/input/images/176.png
# /kaggle/input/images/660.png
# /kaggle/input/images/727.png
# /kaggle/input/images/95.png
# /kaggle/input/images/432.png
# /kaggle/input/images/97.png
# /kaggle/input/images/124.png
# /kaggle/input/images/119.png
# /kaggle/input/images/256.png
# /kaggle/input/images/791.png
# /kaggle/input/images/654.png
# /kaggle/input/images/100.png
# /kaggle/input/images/211.png
# /kaggle/input/images/500.png
# /kaggle/input/images/322.png
# /kaggle/input/images/76.png
# /kaggle/input/images/193.png
# /kaggle/input/images/608.png
# /kaggle/input/images/191.png
# /kaggle/input/images/420.png
# /kaggle/input/images/528.png
# /kaggle/input/images/163.png
# /kaggle/input/images/31.png
# /kaggle/input/images/623.png
# /kaggle/input/images/642.png
# /kaggle/input/images/138.png
# /kaggle/input/images/629.png
# /kaggle/input/images/396.png
# /kaggle/input/images/4.png
# /kaggle/input/images/796.png
# /kaggle/input/images/225.png
# /kaggle/input/images/561.png
# /kaggle/input/images/588.png
# /kaggle/input/images/492.png
# /kaggle/input/images/669.png
# /kaggle/input/images/192.png
# /kaggle/input/images/43.png
# /kaggle/input/images/229.png
# /kaggle/input/images/635.png
# /kaggle/input/images/129.png
# /kaggle/input/images/331.png
# /kaggle/input/images/313.png
# /kaggle/input/images/672.png
# /kaggle/input/images/580.png
# /kaggle/input/images/345.png
# /kaggle/input/images/171.png
# /kaggle/input/images/682.png
# /kaggle/input/images/287.png
# /kaggle/input/images/324.png
# /kaggle/input/images/145.png
# /kaggle/input/images/40.png
# /kaggle/input/images/209.png
# /kaggle/input/images/197.png
# /kaggle/input/images/445.png
# /kaggle/input/images/575.png
# /kaggle/input/images/311.png
# /kaggle/input/images/33.png
# /kaggle/input/images/126.png
# /kaggle/input/images/147.png
# /kaggle/input/images/688.png
# /kaggle/input/images/468.png
# /kaggle/input/images/326.png
# /kaggle/input/images/357.png
# /kaggle/input/images/85.png
# /kaggle/input/images/9.png
# /kaggle/input/images/604.png
# /kaggle/input/images/102.png
# /kaggle/input/images/254.png
# /kaggle/input/images/673.png
# /kaggle/input/images/245.png
# /kaggle/input/images/658.png
# /kaggle/input/images/431.png
# /kaggle/input/images/465.png
# /kaggle/input/images/647.png
# /kaggle/input/images/466.png
# /kaggle/input/images/689.png
# /kaggle/input/images/168.png
# /kaggle/input/images/233.png
# /kaggle/input/images/200.png
# /kaggle/input/images/743.png
# /kaggle/input/images/255.png
# /kaggle/input/images/713.png
# /kaggle/input/images/284.png
# /kaggle/input/images/546.png
# /kaggle/input/images/56.png
# /kaggle/input/images/515.png
# /kaggle/input/images/578.png
# /kaggle/input/images/116.png
# /kaggle/input/images/547.png
# /kaggle/input/images/555.png
# /kaggle/input/images/533.png
# /kaggle/input/images/520.png
# /kaggle/input/images/299.png
# /kaggle/input/images/488.png
# /kaggle/input/images/80.png
# /kaggle/input/images/698.png
# /kaggle/input/images/55.png
# /kaggle/input/images/378.png
# /kaggle/input/images/280.png
# /kaggle/input/images/130.png
# /kaggle/input/images/592.png
# /kaggle/input/images/586.png
# /kaggle/input/images/522.png
# /kaggle/input/images/291.png
# /kaggle/input/images/443.png
# /kaggle/input/images/50.png
# /kaggle/input/images/288.png
# /kaggle/input/images/307.png
# /kaggle/input/images/218.png
# /kaggle/input/images/589.png
# /kaggle/input/images/607.png
# /kaggle/input/images/405.png
# /kaggle/input/images/779.png
# /kaggle/input/images/199.png
# /kaggle/input/images/112.png
# /kaggle/input/images/755.png
# /kaggle/input/images/763.png
# /kaggle/input/images/788.png
# /kaggle/input/images/501.png
# /kaggle/input/images/723.png
# /kaggle/input/images/49.png
# /kaggle/input/images/327.png
# /kaggle/input/images/599.png
# /kaggle/input/images/747.png
# /kaggle/input/images/552.png
# /kaggle/input/images/268.png
# /kaggle/input/images/775.png
# /kaggle/input/images/93.png
# /kaggle/input/images/395.png
# /kaggle/input/images/150.png
# /kaggle/input/images/705.png
# /kaggle/input/images/774.png
# /kaggle/input/images/113.png
# /kaggle/input/images/741.png
# /kaggle/input/images/332.png
# /kaggle/input/images/59.png
# /kaggle/input/images/674.png
# /kaggle/input/images/316.png
# /kaggle/input/images/785.png
# /kaggle/input/images/434.png
# /kaggle/input/images/169.png
# /kaggle/input/images/529.png
# /kaggle/input/images/301.png
# /kaggle/input/images/289.png
# /kaggle/input/images/170.png
# /kaggle/input/images/194.png
# /kaggle/input/images/136.png
# /kaggle/input/images/198.png
# /kaggle/input/images/724.png
# /kaggle/input/images/683.png
# /kaggle/input/images/640.png
# /kaggle/input/images/401.png
# /kaggle/input/images/14.png
# /kaggle/input/images/65.png
# /kaggle/input/images/161.png
# /kaggle/input/images/371.png
# /kaggle/input/images/784.png
# /kaggle/input/images/1.png
# /kaggle/input/images/706.png
# /kaggle/input/images/293.png
# /kaggle/input/images/576.png
# /kaggle/input/images/798.png
# /kaggle/input/images/574.png
# /kaggle/input/images/701.png
# /kaggle/input/images/367.png
# /kaggle/input/images/484.png
# /kaggle/input/images/325.png
# /kaggle/input/images/108.png
# /kaggle/input/images/39.png
# /kaggle/input/images/360.png
# /kaggle/input/images/748.png
# /kaggle/input/images/458.png
# /kaggle/input/images/380.png
# /kaggle/input/images/610.png
# /kaggle/input/images/446.png
# /kaggle/input/images/132.png
# /kaggle/input/images/424.png
# /kaggle/input/images/781.png
# /kaggle/input/images/715.png
# /kaggle/input/images/386.png
# /kaggle/input/images/549.png
# /kaggle/input/images/433.png
# /kaggle/input/images/156.png
# /kaggle/input/images/370.png
# /kaggle/input/images/767.png
# /kaggle/input/images/777.png
# /kaggle/input/images/319.png
# /kaggle/input/images/696.png
# /kaggle/input/images/609.png
# /kaggle/input/images/107.png
# /kaggle/input/images/790.png
# /kaggle/input/images/372.png
# /kaggle/input/images/90.png
# /kaggle/input/images/262.png
# /kaggle/input/images/364.png
# /kaggle/input/images/215.png
# /kaggle/input/images/769.png
# /kaggle/input/images/414.png
# /kaggle/input/images/614.png
# /kaggle/input/images/439.png
# /kaggle/input/images/20.png
# /kaggle/input/images/181.png
# /kaggle/input/images/471.png
# /kaggle/input/images/83.png
# /kaggle/input/images/412.png
# /kaggle/input/images/597.png
# /kaggle/input/images/467.png
# /kaggle/input/images/473.png
# /kaggle/input/images/587.png
# /kaggle/input/images/426.png
# /kaggle/input/images/770.png
# /kaggle/input/images/731.png
# /kaggle/input/images/389.png
# /kaggle/input/images/691.png
# /kaggle/input/images/38.png
# /kaggle/input/images/151.png
# /kaggle/input/images/2.png
# /kaggle/input/images/530.png
# /kaggle/input/images/349.png
# /kaggle/input/images/702.png
# /kaggle/input/images/335.png
# /kaggle/input/images/223.png
# /kaggle/input/images/272.png
# /kaggle/input/images/10.png
# /kaggle/input/images/598.png
# /kaggle/input/images/82.png
# /kaggle/input/images/460.png
# /kaggle/input/images/242.png
# /kaggle/input/images/404.png
# /kaggle/input/images/251.png
# /kaggle/input/images/174.png
# /kaggle/input/images/250.png
# /kaggle/input/images/440.png
# /kaggle/input/images/131.png
# /kaggle/input/images/397.png
# /kaggle/input/images/36.png
# /kaggle/input/images/157.png
# /kaggle/input/images/182.png
# /kaggle/input/images/143.png
# /kaggle/input/images/221.png
# /kaggle/input/images/746.png
# /kaggle/input/images/387.png
# /kaggle/input/images/383.png
# /kaggle/input/images/570.png
# /kaggle/input/images/700.png
# /kaggle/input/images/208.png
# /kaggle/input/images/152.png
# /kaggle/input/images/137.png
# /kaggle/input/images/556.png
# /kaggle/input/images/312.png
# /kaggle/input/images/81.png
# /kaggle/input/images/239.png
# /kaggle/input/images/66.png
# /kaggle/input/images/58.png
# /kaggle/input/images/661.png
# /kaggle/input/images/453.png
# /kaggle/input/images/417.png
# /kaggle/input/images/483.png
# /kaggle/input/images/764.png
# /kaggle/input/images/732.png
# /kaggle/input/images/214.png
# /kaggle/input/images/122.png
# /kaggle/input/images/392.png
# /kaggle/input/images/639.png
# /kaggle/input/images/684.png
# /kaggle/input/images/712.png
# /kaggle/input/images/735.png
# /kaggle/input/images/734.png
# /kaggle/input/images/722.png
# /kaggle/input/images/339.png
# /kaggle/input/images/276.png
# /kaggle/input/images/187.png
# /kaggle/input/images/106.png
# /kaggle/input/images/585.png
# /kaggle/input/images/336.png
# /kaggle/input/images/279.png
# /kaggle/input/images/577.png
# /kaggle/input/images/356.png
# /kaggle/input/images/117.png
# /kaggle/input/images/220.png
# /kaggle/input/images/391.png
# /kaggle/input/images/277.png
# /kaggle/input/images/617.png
# /kaggle/input/images/584.png
# /kaggle/input/images/300.png
# /kaggle/input/images/667.png
# /kaggle/input/images/425.png
# /kaggle/input/images/244.png
# /kaggle/input/images/329.png
# /kaggle/input/images/282.png
# /kaggle/input/images/263.png
# /kaggle/input/images/354.png
# /kaggle/input/images/650.png
# /kaggle/input/images/166.png
# /kaggle/input/images/594.png
# /kaggle/input/images/582.png
# /kaggle/input/images/680.png
# /kaggle/input/images/320.png
# /kaggle/input/images/437.png
# /kaggle/input/images/572.png
# /kaggle/input/images/18.png
# /kaggle/input/images/63.png
# /kaggle/input/images/455.png
# /kaggle/input/images/435.png
# /kaggle/input/images/294.png
# /kaggle/input/images/534.png
# /kaggle/input/images/745.png
# /kaggle/input/images/264.png
# /kaggle/input/images/21.png
# /kaggle/input/images/495.png
# /kaggle/input/images/12.png
# /kaggle/input/images/739.png
# /kaggle/input/images/514.png
# /kaggle/input/images/616.png
# /kaggle/input/images/720.png
# /kaggle/input/images/792.png
# /kaggle/input/images/98.png
# /kaggle/input/images/524.png
# /kaggle/input/images/127.png
# /kaggle/input/images/666.png
# /kaggle/input/images/415.png
# /kaggle/input/images/553.png
# /kaggle/input/images/219.png
# /kaggle/input/images/184.png
# /kaggle/input/images/782.png
# /kaggle/input/images/757.png
# /kaggle/input/images/795.png
# /kaggle/input/images/627.png
# /kaggle/input/images/751.png
# /kaggle/input/images/510.png
# /kaggle/input/images/28.png
# /kaggle/input/images/190.png
# /kaggle/input/images/490.png
# /kaggle/input/images/165.png
# /kaggle/input/images/402.png
# /kaggle/input/images/464.png
# /kaggle/input/images/22.png
# /kaggle/input/images/202.png
# /kaggle/input/images/247.png
# /kaggle/input/images/368.png
# /kaggle/input/images/758.png
# /kaggle/input/images/469.png
# /kaggle/input/images/602.png
# /kaggle/input/images/799.png
# /kaggle/input/images/476.png
# /kaggle/input/images/481.png
# /kaggle/input/images/559.png
# /kaggle/input/images/447.png
# /kaggle/input/images/625.png
# /kaggle/input/images/742.png
# /kaggle/input/images/67.png
# /kaggle/input/images/96.png
# /kaggle/input/images/243.png
# /kaggle/input/images/502.png
# /kaggle/input/images/603.png
# /kaggle/input/images/34.png
# /kaggle/input/images/509.png
# /kaggle/input/images/690.png
# /kaggle/input/images/41.png
# /kaggle/input/images/733.png
# /kaggle/input/images/159.png
# /kaggle/input/images/662.png
# /kaggle/input/images/563.png
# /kaggle/input/images/551.png
# /kaggle/input/images/685.png
# /kaggle/input/images/554.png
# /kaggle/input/images/756.png
# /kaggle/input/images/596.png
# /kaggle/input/images/246.png
# /kaggle/input/images/195.png
# /kaggle/input/images/105.png
# /kaggle/input/images/479.png
# /kaggle/input/images/612.png
# /kaggle/input/images/125.png
# /kaggle/input/images/121.png
# /kaggle/input/images/318.png
# /kaggle/input/images/216.png
# /kaggle/input/images/656.png
# /kaggle/input/images/337.png
# /kaggle/input/images/69.png
# /kaggle/input/images/146.png
# /kaggle/input/images/154.png
# /kaggle/input/images/637.png
# /kaggle/input/images/267.png
# /kaggle/input/images/7.png
# /kaggle/input/images/663.png
# /kaggle/input/images/374.png
# /kaggle/input/images/366.png
# /kaggle/input/images/241.png
# /kaggle/input/images/188.png
# /kaggle/input/images/716.png
# /kaggle/input/images/86.png
# /kaggle/input/images/776.png
# /kaggle/input/images/258.png
# /kaggle/input/images/77.png
# /kaggle/input/images/498.png
# /kaggle/input/images/290.png
# /kaggle/input/images/29.png
# /kaggle/input/images/265.png
# /kaggle/input/images/638.png
# /kaggle/input/images/103.png
# /kaggle/input/images/632.png
# /kaggle/input/images/72.png
# /kaggle/input/images/144.png
# /kaggle/input/images/298.png
# /kaggle/input/images/472.png
# /kaggle/input/images/503.png
# /kaggle/input/images/695.png
# /kaggle/input/images/644.png
# /kaggle/input/images/456.png
# /kaggle/input/images/540.png
# /kaggle/input/images/109.png
# /kaggle/input/images/496.png
# /kaggle/input/images/714.png
# /kaggle/input/images/697.png
# /kaggle/input/images/224.png
# /kaggle/input/images/361.png
# /kaggle/input/images/753.png
# /kaggle/input/images/567.png
# /kaggle/input/images/526.png
# /kaggle/input/images/527.png
# /kaggle/input/images/71.png
# /kaggle/input/images/648.png
# /kaggle/input/images/595.png
# /kaggle/input/images/573.png
# /kaggle/input/images/74.png
# /kaggle/input/images/653.png
# /kaggle/input/images/525.png
# /kaggle/input/images/120.png
# /kaggle/input/images/630.png
# /kaggle/input/images/271.png
# /kaggle/input/images/363.png
# /kaggle/input/images/310.png
# /kaggle/input/images/323.png
# /kaggle/input/images/118.png
# /kaggle/input/images/772.png
# /kaggle/input/images/670.png
# /kaggle/input/images/393.png
# /kaggle/input/images/17.png
# /kaggle/input/images/53.png
# /kaggle/input/images/266.png
# /kaggle/input/images/486.png
# /kaggle/input/images/657.png
# /kaggle/input/images/196.png
# /kaggle/input/images/626.png
# /kaggle/input/images/571.png
# /kaggle/input/images/179.png
# /kaggle/input/images/178.png
# /kaggle/input/images/160.png
# /kaggle/input/images/671.png
# /kaggle/input/images/140.png
# /kaggle/input/images/620.png
# /kaggle/input/images/636.png
# /kaggle/input/images/736.png
# /kaggle/input/images/52.png
# /kaggle/input/images/793.png
# /kaggle/input/images/5.png
# /kaggle/input/images/139.png
# /kaggle/input/images/3.png
# /kaggle/input/images/172.png
# /kaggle/input/images/64.png
# /kaggle/input/images/406.png
# /kaggle/input/images/719.png
# /kaggle/input/images/347.png
# /kaggle/input/images/665.png
# /kaggle/input/images/355.png
# /kaggle/input/images/16.png
# /kaggle/input/images/438.png
# /kaggle/input/images/430.png
# /kaggle/input/images/545.png
# /kaggle/input/images/409.png
# /kaggle/input/images/725.png
# /kaggle/input/images/328.png
# /kaggle/input/images/423.png
# /kaggle/input/images/643.png
# /kaggle/input/images/461.png
# /kaggle/input/images/375.png
# /kaggle/input/images/760.png
# /kaggle/input/images/203.png
# /kaggle/input/images/8.png
# /kaggle/input/images/489.png
# /kaggle/input/images/45.png
# /kaggle/input/images/382.png
# /kaggle/input/images/24.png
# /kaggle/input/images/548.png
# /kaggle/input/images/444.png
# /kaggle/input/images/373.png
# /kaggle/input/images/32.png
# /kaggle/input/images/88.png
# /kaggle/input/images/463.png
# /kaggle/input/images/649.png
# /kaggle/input/images/624.png
# /kaggle/input/images/283.png
# /kaggle/input/images/274.png
# /kaggle/input/images/115.png
# /kaggle/input/images/749.png
# /kaggle/input/images/249.png
# /kaggle/input/images/128.png
# /kaggle/input/images/668.png
# /kaggle/input/images/158.png
# /kaggle/input/images/583.png
# /kaggle/input/images/710.png
# /kaggle/input/images/6.png
# /kaggle/input/images/23.png
# /kaggle/input/images/87.png
# /kaggle/input/images/686.png
# /kaggle/input/images/275.png
# /kaggle/input/images/787.png
# /kaggle/input/images/51.png
# /kaggle/input/images/703.png
# /kaggle/input/images/728.png
# /kaggle/input/images/591.png
# /kaggle/input/images/400.png
# /kaggle/input/images/101.png
# /kaggle/input/images/606.png
# /kaggle/input/images/618.png
# /kaggle/input/images/536.png
# /kaggle/input/images/717.png
# /kaggle/input/images/297.png
# /kaggle/input/images/135.png
# /kaggle/input/images/794.png
# /kaggle/input/images/482.png
# /kaggle/input/images/797.png
# /kaggle/input/images/740.png
# /kaggle/input/images/512.png
# /kaggle/input/images/123.png
# /kaggle/input/images/91.png
# /kaggle/input/images/504.png
# /kaggle/input/images/230.png
# /kaggle/input/images/738.png
# /kaggle/input/images/478.png
# /kaggle/input/images/44.png
# /kaggle/input/images/399.png
# /kaggle/input/images/189.png
# /kaggle/input/images/541.png
# /kaggle/input/images/601.png
# /kaggle/input/images/442.png
# /kaggle/input/images/343.png
# /kaggle/input/images/454.png
# /kaggle/input/images/730.png
# /kaggle/input/images/410.png
# /kaggle/input/images/68.png
# /kaggle/input/images/422.png
# /kaggle/input/images/286.png
# /kaggle/input/images/180.png
# /kaggle/input/images/46.png
# /kaggle/input/images/508.png
# /kaggle/input/images/499.png
# /kaggle/input/images/711.png
# /kaggle/input/images/664.png
# /kaggle/input/images/516.png
# /kaggle/input/images/470.png
# /kaggle/input/images/57.png
# /kaggle/input/images/448.png
# /kaggle/input/images/84.png
# /kaggle/input/images/475.png
# /kaggle/input/images/564.png
# /kaggle/input/images/687.png
# /kaggle/input/images/15.png
# /kaggle/input/images/210.png
# /kaggle/input/images/234.png
# /kaggle/input/images/358.png
# /kaggle/input/images/365.png
# /kaggle/input/images/652.png
# /kaggle/input/images/252.png
# /kaggle/input/images/531.png
# /kaggle/input/images/507.png
# /kaggle/input/images/704.png
# /kaggle/input/images/565.png
# /kaggle/input/images/679.png
# /kaggle/input/images/523.png
# /kaggle/input/images/183.png
# /kaggle/input/images/678.png
# /kaggle/input/images/450.png
# /kaggle/input/images/30.png
# /kaggle/input/images/485.png
# /kaggle/input/images/408.png
# /kaggle/input/images/631.png
# /kaggle/input/images/708.png
# /kaggle/input/images/569.png
# /kaggle/input/images/427.png
# /kaggle/input/images/619.png
# /kaggle/input/images/622.png
# /kaggle/input/images/537.png
# /kaggle/input/images/429.png
# /kaggle/input/images/783.png
# /kaggle/input/images/321.png
# /kaggle/input/images/60.png
# /kaggle/input/images/235.png
# /kaggle/input/images/99.png
# /kaggle/input/images/155.png
# /kaggle/input/images/765.png
# /kaggle/input/images/593.png
# /kaggle/input/images/676.png
# /kaggle/input/images/228.png
# /kaggle/input/images/27.png
# /kaggle/input/images/390.png
# /kaggle/input/images/237.png
# /kaggle/input/images/451.png
# /kaggle/input/images/692.png
# /kaggle/input/images/474.png
# /kaggle/input/images/292.png
# /kaggle/input/images/421.png
# /kaggle/input/images/201.png
# /kaggle/input/images/539.png
# /kaggle/input/images/519.png
# /kaggle/input/images/295.png
# /kaggle/input/images/394.png
# /kaggle/input/images/273.png
# /kaggle/input/images/269.png
# /kaggle/input/images/459.png
# /kaggle/input/images/413.png
# /kaggle/input/images/773.png
# /kaggle/input/images/78.png
# /kaggle/input/images/212.png
# /kaggle/input/images/47.png
# /kaggle/input/images/786.png
# /kaggle/input/images/207.png
# /kaggle/input/images/149.png
# /kaggle/input/images/487.png
# /kaggle/input/images/13.png
# /kaggle/input/images/535.png
# /kaggle/input/images/260.png
# /kaggle/input/images/253.png
# /kaggle/input/images/206.png
# /kaggle/input/images/789.png
# /kaggle/input/images/557.png
# /kaggle/input/images/613.png
# /kaggle/input/images/600.png
# /kaggle/input/images/381.png
# /kaggle/input/images/342.png
# /kaggle/input/images/346.png
# /kaggle/input/images/134.png
# /kaggle/input/images/721.png
# /kaggle/input/images/694.png
# /kaggle/input/images/590.png
# /kaggle/input/images/566.png
# /kaggle/input/images/259.png
# /kaggle/input/images/25.png
# /kaggle/input/images/285.png
# /kaggle/input/images/341.png
# /kaggle/input/images/54.png
# /kaggle/input/images/462.png
# /kaggle/input/images/558.png
# /kaggle/input/images/111.png
# /kaggle/input/images/611.png
# /kaggle/input/images/62.png
# /kaggle/input/images/205.png
# /kaggle/input/images/699.png
# /kaggle/input/images/369.png
# /kaggle/input/images/750.png
# /kaggle/input/images/0.png
# /kaggle/input/images/141.png
# /kaggle/input/images/693.png
# /kaggle/input/images/532.png
# /kaggle/input/images/309.png
# /kaggle/input/images/560.png
# /kaggle/input/images/19.png
# /kaggle/input/images/110.png
# /kaggle/input/images/544.png
# /kaggle/input/images/308.png
# /kaggle/input/images/26.png
# /kaggle/input/images/568.png
# /kaggle/input/images/388.png
# /kaggle/input/images/79.png
# /kaggle/input/images/633.png
# /kaggle/input/images/729.png
# /kaggle/input/images/257.png
# /kaggle/input/images/305.png
# /kaggle/input/images/477.png
# /kaggle/input/images/42.png
# /kaggle/input/images/175.png
# /kaggle/input/images/518.png
# /kaggle/input/images/226.png
# /kaggle/input/images/428.png
# /kaggle/input/images/217.png
# /kaggle/input/images/494.png
# /kaggle/input/images/659.png
# /kaggle/input/images/418.png
# /kaggle/input/images/452.png
# /kaggle/input/images/306.png
# /kaggle/input/images/497.png
# /kaggle/input/images/304.png
# /kaggle/input/masks/700-mask.png
# /kaggle/input/masks/525-mask.png
# /kaggle/input/masks/321-mask.png
# /kaggle/input/masks/687-mask.png
# /kaggle/input/masks/721-mask.png
# /kaggle/input/masks/317-mask.png
# /kaggle/input/masks/330-mask.png
# /kaggle/input/masks/607-mask.png
# /kaggle/input/masks/98-mask.png
# /kaggle/input/masks/749-mask.png
# /kaggle/input/masks/51-mask.png
# /kaggle/input/masks/72-mask.png
# /kaggle/input/masks/609-mask.png
# /kaggle/input/masks/527-mask.png
# /kaggle/input/masks/80-mask.png
# /kaggle/input/masks/622-mask.png
# /kaggle/input/masks/70-mask.png
# /kaggle/input/masks/203-mask.png
# /kaggle/input/masks/583-mask.png
# /kaggle/input/masks/126-mask.png
# /kaggle/input/masks/247-mask.png
# /kaggle/input/masks/735-mask.png
# /kaggle/input/masks/497-mask.png
# /kaggle/input/masks/646-mask.png
# /kaggle/input/masks/452-mask.png
# /kaggle/input/masks/420-mask.png
# /kaggle/input/masks/449-mask.png
# /kaggle/input/masks/463-mask.png
# /kaggle/input/masks/737-mask.png
# /kaggle/input/masks/183-mask.png
# /kaggle/input/masks/581-mask.png
# /kaggle/input/masks/716-mask.png
# /kaggle/input/masks/684-mask.png
# /kaggle/input/masks/21-mask.png
# /kaggle/input/masks/678-mask.png
# /kaggle/input/masks/580-mask.png
# /kaggle/input/masks/146-mask.png
# /kaggle/input/masks/366-mask.png
# /kaggle/input/masks/322-mask.png
# /kaggle/input/masks/435-mask.png
# /kaggle/input/masks/759-mask.png
# /kaggle/input/masks/584-mask.png
# /kaggle/input/masks/368-mask.png
# /kaggle/input/masks/344-mask.png
# /kaggle/input/masks/725-mask.png
# /kaggle/input/masks/239-mask.png
# /kaggle/input/masks/119-mask.png
# /kaggle/input/masks/29-mask.png
# /kaggle/input/masks/620-mask.png
# /kaggle/input/masks/170-mask.png
# /kaggle/input/masks/220-mask.png
# /kaggle/input/masks/364-mask.png
# /kaggle/input/masks/524-mask.png
# /kaggle/input/masks/78-mask.png
# /kaggle/input/masks/707-mask.png
# /kaggle/input/masks/31-mask.png
# /kaggle/input/masks/12-mask.png
# /kaggle/input/masks/556-mask.png
# /kaggle/input/masks/5-mask.png
# /kaggle/input/masks/480-mask.png
# /kaggle/input/masks/783-mask.png
# /kaggle/input/masks/71-mask.png
# /kaggle/input/masks/423-mask.png
# /kaggle/input/masks/173-mask.png
# /kaggle/input/masks/131-mask.png
# /kaggle/input/masks/85-mask.png
# /kaggle/input/masks/347-mask.png
# /kaggle/input/masks/350-mask.png
# /kaggle/input/masks/133-mask.png
# /kaggle/input/masks/472-mask.png
# /kaggle/input/masks/695-mask.png
# /kaggle/input/masks/265-mask.png
# /kaggle/input/masks/280-mask.png
# /kaggle/input/masks/766-mask.png
# /kaggle/input/masks/664-mask.png
# /kaggle/input/masks/778-mask.png
# /kaggle/input/masks/23-mask.png
# /kaggle/input/masks/315-mask.png
# /kaggle/input/masks/661-mask.png
# /kaggle/input/masks/593-mask.png
# /kaggle/input/masks/652-mask.png
# /kaggle/input/masks/653-mask.png
# /kaggle/input/masks/16-mask.png
# /kaggle/input/masks/120-mask.png
# /kaggle/input/masks/145-mask.png
# /kaggle/input/masks/705-mask.png
# /kaggle/input/masks/159-mask.png
# /kaggle/input/masks/555-mask.png
# /kaggle/input/masks/284-mask.png
# /kaggle/input/masks/445-mask.png
# /kaggle/input/masks/143-mask.png
# /kaggle/input/masks/407-mask.png
# /kaggle/input/masks/549-mask.png
# /kaggle/input/masks/736-mask.png
# /kaggle/input/masks/381-mask.png
# /kaggle/input/masks/67-mask.png
# /kaggle/input/masks/535-mask.png
# /kaggle/input/masks/464-mask.png
# /kaggle/input/masks/676-mask.png
# /kaggle/input/masks/399-mask.png
# /kaggle/input/masks/501-mask.png
# /kaggle/input/masks/157-mask.png
# /kaggle/input/masks/462-mask.png
# /kaggle/input/masks/327-mask.png
# /kaggle/input/masks/227-mask.png
# /kaggle/input/masks/39-mask.png
# /kaggle/input/masks/18-mask.png
# /kaggle/input/masks/232-mask.png
# /kaggle/input/masks/512-mask.png
# /kaggle/input/masks/201-mask.png
# /kaggle/input/masks/448-mask.png
# /kaggle/input/masks/473-mask.png
# /kaggle/input/masks/388-mask.png
# /kaggle/input/masks/324-mask.png
# /kaggle/input/masks/245-mask.png
# /kaggle/input/masks/194-mask.png
# /kaggle/input/masks/169-mask.png
# /kaggle/input/masks/726-mask.png
# /kaggle/input/masks/181-mask.png
# /kaggle/input/masks/167-mask.png
# /kaggle/input/masks/132-mask.png
# /kaggle/input/masks/213-mask.png
# /kaggle/input/masks/550-mask.png
# /kaggle/input/masks/456-mask.png
# /kaggle/input/masks/559-mask.png
# /kaggle/input/masks/222-mask.png
# /kaggle/input/masks/604-mask.png
# /kaggle/input/masks/338-mask.png
# /kaggle/input/masks/172-mask.png
# /kaggle/input/masks/754-mask.png
# /kaggle/input/masks/136-mask.png
# /kaggle/input/masks/308-mask.png
# /kaggle/input/masks/451-mask.png
# /kaggle/input/masks/379-mask.png
# /kaggle/input/masks/262-mask.png
# /kaggle/input/masks/228-mask.png
# /kaggle/input/masks/285-mask.png
# /kaggle/input/masks/114-mask.png
# /kaggle/input/masks/286-mask.png
# /kaggle/input/masks/7-mask.png
# /kaggle/input/masks/360-mask.png
# /kaggle/input/masks/410-mask.png
# /kaggle/input/masks/571-mask.png
# /kaggle/input/masks/459-mask.png
# /kaggle/input/masks/205-mask.png
# /kaggle/input/masks/27-mask.png
# /kaggle/input/masks/335-mask.png
# /kaggle/input/masks/176-mask.png
# /kaggle/input/masks/677-mask.png
# /kaggle/input/masks/508-mask.png
# /kaggle/input/masks/291-mask.png
# /kaggle/input/masks/402-mask.png
# /kaggle/input/masks/667-mask.png
# /kaggle/input/masks/369-mask.png
# /kaggle/input/masks/732-mask.png
# /kaggle/input/masks/444-mask.png
# /kaggle/input/masks/536-mask.png
# /kaggle/input/masks/479-mask.png
# /kaggle/input/masks/66-mask.png
# /kaggle/input/masks/123-mask.png
# /kaggle/input/masks/376-mask.png
# /kaggle/input/masks/274-mask.png
# /kaggle/input/masks/212-mask.png
# /kaggle/input/masks/101-mask.png
# /kaggle/input/masks/446-mask.png
# /kaggle/input/masks/657-mask.png
# /kaggle/input/masks/471-mask.png
# /kaggle/input/masks/216-mask.png
# /kaggle/input/masks/153-mask.png
# /kaggle/input/masks/796-mask.png
# /kaggle/input/masks/514-mask.png
# /kaggle/input/masks/275-mask.png
# /kaggle/input/masks/416-mask.png
# /kaggle/input/masks/48-mask.png
# /kaggle/input/masks/117-mask.png
# /kaggle/input/masks/393-mask.png
# /kaggle/input/masks/141-mask.png
# /kaggle/input/masks/339-mask.png
# /kaggle/input/masks/52-mask.png
# /kaggle/input/masks/163-mask.png
# /kaggle/input/masks/741-mask.png
# /kaggle/input/masks/694-mask.png
# /kaggle/input/masks/200-mask.png
# /kaggle/input/masks/314-mask.png
# /kaggle/input/masks/429-mask.png
# /kaggle/input/masks/753-mask.png
# /kaggle/input/masks/267-mask.png
# /kaggle/input/masks/42-mask.png
# /kaggle/input/masks/279-mask.png
# /kaggle/input/masks/693-mask.png
# /kaggle/input/masks/433-mask.png
# /kaggle/input/masks/706-mask.png
# /kaggle/input/masks/437-mask.png
# /kaggle/input/masks/426-mask.png
# /kaggle/input/masks/747-mask.png
# /kaggle/input/masks/793-mask.png
# /kaggle/input/masks/24-mask.png
# /kaggle/input/masks/650-mask.png
# /kaggle/input/masks/180-mask.png
# /kaggle/input/masks/688-mask.png
# /kaggle/input/masks/235-mask.png
# /kaggle/input/masks/192-mask.png
# /kaggle/input/masks/436-mask.png
# /kaggle/input/masks/748-mask.png
# /kaggle/input/masks/231-mask.png
# /kaggle/input/masks/238-mask.png
# /kaggle/input/masks/440-mask.png
# /kaggle/input/masks/710-mask.png
# /kaggle/input/masks/786-mask.png
# /kaggle/input/masks/349-mask.png
# /kaggle/input/masks/13-mask.png
# /kaggle/input/masks/310-mask.png
# /kaggle/input/masks/499-mask.png
# /kaggle/input/masks/613-mask.png
# /kaggle/input/masks/14-mask.png
# /kaggle/input/masks/511-mask.png
# /kaggle/input/masks/287-mask.png
# /kaggle/input/masks/408-mask.png
# /kaggle/input/masks/225-mask.png
# /kaggle/input/masks/135-mask.png
# /kaggle/input/masks/142-mask.png
# /kaggle/input/masks/680-mask.png
# /kaggle/input/masks/719-mask.png
# /kaggle/input/masks/523-mask.png
# /kaggle/input/masks/282-mask.png
# /kaggle/input/masks/561-mask.png
# /kaggle/input/masks/148-mask.png
# /kaggle/input/masks/718-mask.png
# /kaggle/input/masks/560-mask.png
# /kaggle/input/masks/769-mask.png
# /kaggle/input/masks/562-mask.png
# /kaggle/input/masks/352-mask.png
# /kaggle/input/masks/22-mask.png
# /kaggle/input/masks/728-mask.png
# /kaggle/input/masks/784-mask.png
# /kaggle/input/masks/470-mask.png
# /kaggle/input/masks/128-mask.png
# /kaggle/input/masks/303-mask.png
# /kaggle/input/masks/779-mask.png
# /kaggle/input/masks/395-mask.png
# /kaggle/input/masks/193-mask.png
# /kaggle/input/masks/522-mask.png
# /kaggle/input/masks/740-mask.png
# /kaggle/input/masks/37-mask.png
# /kaggle/input/masks/422-mask.png
# /kaggle/input/masks/112-mask.png
# /kaggle/input/masks/248-mask.png
# /kaggle/input/masks/99-mask.png
# /kaggle/input/masks/346-mask.png
# /kaggle/input/masks/631-mask.png
# /kaggle/input/masks/566-mask.png
# /kaggle/input/masks/198-mask.png
# /kaggle/input/masks/377-mask.png
# /kaggle/input/masks/253-mask.png
# /kaggle/input/masks/336-mask.png
# /kaggle/input/masks/768-mask.png
# /kaggle/input/masks/292-mask.png
# /kaggle/input/masks/685-mask.png
# /kaggle/input/masks/108-mask.png
# /kaggle/input/masks/443-mask.png
# /kaggle/input/masks/318-mask.png
# /kaggle/input/masks/510-mask.png
# /kaggle/input/masks/397-mask.png
# /kaggle/input/masks/692-mask.png
# /kaggle/input/masks/645-mask.png
# /kaggle/input/masks/528-mask.png
# /kaggle/input/masks/140-mask.png
# /kaggle/input/masks/777-mask.png
# /kaggle/input/masks/26-mask.png
# /kaggle/input/masks/40-mask.png
# /kaggle/input/masks/704-mask.png
# /kaggle/input/masks/636-mask.png
# /kaggle/input/masks/774-mask.png
# /kaggle/input/masks/656-mask.png
# /kaggle/input/masks/697-mask.png
# /kaggle/input/masks/191-mask.png
# /kaggle/input/masks/765-mask.png
# /kaggle/input/masks/174-mask.png
# /kaggle/input/masks/594-mask.png
# /kaggle/input/masks/723-mask.png
# /kaggle/input/masks/88-mask.png
# /kaggle/input/masks/301-mask.png
# /kaggle/input/masks/374-mask.png
# /kaggle/input/masks/621-mask.png
# /kaggle/input/masks/116-mask.png
# /kaggle/input/masks/553-mask.png
# /kaggle/input/masks/115-mask.png
# /kaggle/input/masks/138-mask.png
# /kaggle/input/masks/345-mask.png
# /kaggle/input/masks/34-mask.png
# /kaggle/input/masks/58-mask.png
# /kaggle/input/masks/313-mask.png
# /kaggle/input/masks/483-mask.png
# /kaggle/input/masks/197-mask.png
# /kaggle/input/masks/626-mask.png
# /kaggle/input/masks/77-mask.png
# /kaggle/input/masks/668-mask.png
# /kaggle/input/masks/79-mask.png
# /kaggle/input/masks/633-mask.png
# /kaggle/input/masks/746-mask.png
# /kaggle/input/masks/105-mask.png
# /kaggle/input/masks/743-mask.png
# /kaggle/input/masks/243-mask.png
# /kaggle/input/masks/56-mask.png
# /kaggle/input/masks/215-mask.png
# /kaggle/input/masks/762-mask.png
# /kaggle/input/masks/268-mask.png
# /kaggle/input/masks/240-mask.png
# /kaggle/input/masks/672-mask.png
# /kaggle/input/masks/544-mask.png
# /kaggle/input/masks/270-mask.png
# /kaggle/input/masks/122-mask.png
# /kaggle/input/masks/391-mask.png
# /kaggle/input/masks/250-mask.png
# /kaggle/input/masks/485-mask.png
# /kaggle/input/masks/74-mask.png
# /kaggle/input/masks/406-mask.png
# /kaggle/input/masks/165-mask.png
# /kaggle/input/masks/615-mask.png
# /kaggle/input/masks/383-mask.png
# /kaggle/input/masks/297-mask.png
# /kaggle/input/masks/460-mask.png
# /kaggle/input/masks/585-mask.png
# /kaggle/input/masks/113-mask.png
# /kaggle/input/masks/188-mask.png
# /kaggle/input/masks/124-mask.png
# /kaggle/input/masks/218-mask.png
# /kaggle/input/masks/83-mask.png
# /kaggle/input/masks/495-mask.png
# /kaggle/input/masks/795-mask.png
# /kaggle/input/masks/90-mask.png
# /kaggle/input/masks/481-mask.png
# /kaggle/input/masks/767-mask.png
# /kaggle/input/masks/332-mask.png
# /kaggle/input/masks/387-mask.png
# /kaggle/input/masks/651-mask.png
# /kaggle/input/masks/498-mask.png
# /kaggle/input/masks/703-mask.png
# /kaggle/input/masks/226-mask.png
# /kaggle/input/masks/19-mask.png
# /kaggle/input/masks/461-mask.png
# /kaggle/input/masks/149-mask.png
# /kaggle/input/masks/787-mask.png
# /kaggle/input/masks/91-mask.png
# /kaggle/input/masks/130-mask.png
# /kaggle/input/masks/189-mask.png
# /kaggle/input/masks/96-mask.png
# /kaggle/input/masks/611-mask.png
# /kaggle/input/masks/343-mask.png
# /kaggle/input/masks/409-mask.png
# /kaggle/input/masks/384-mask.png
# /kaggle/input/masks/60-mask.png
# /kaggle/input/masks/329-mask.png
# /kaggle/input/masks/634-mask.png
# /kaggle/input/masks/107-mask.png
# /kaggle/input/masks/751-mask.png
# /kaggle/input/masks/390-mask.png
# /kaggle/input/masks/187-mask.png
# /kaggle/input/masks/398-mask.png
# /kaggle/input/masks/752-mask.png
# /kaggle/input/masks/404-mask.png
# /kaggle/input/masks/428-mask.png
# /kaggle/input/masks/545-mask.png
# /kaggle/input/masks/627-mask.png
# /kaggle/input/masks/266-mask.png
# /kaggle/input/masks/624-mask.png
# /kaggle/input/masks/565-mask.png
# /kaggle/input/masks/254-mask.png
# /kaggle/input/masks/542-mask.png
# /kaggle/input/masks/474-mask.png
# /kaggle/input/masks/418-mask.png
# /kaggle/input/masks/41-mask.png
# /kaggle/input/masks/558-mask.png
# /kaggle/input/masks/727-mask.png
# /kaggle/input/masks/515-mask.png
# /kaggle/input/masks/171-mask.png
# /kaggle/input/masks/283-mask.png
# /kaggle/input/masks/396-mask.png
# /kaggle/input/masks/134-mask.png
# /kaggle/input/masks/289-mask.png
# /kaggle/input/masks/204-mask.png
# /kaggle/input/masks/380-mask.png
# /kaggle/input/masks/269-mask.png
# /kaggle/input/masks/233-mask.png
# /kaggle/input/masks/111-mask.png
# /kaggle/input/masks/629-mask.png
# /kaggle/input/masks/733-mask.png
# /kaggle/input/masks/534-mask.png
# /kaggle/input/masks/389-mask.png
# /kaggle/input/masks/76-mask.png
# /kaggle/input/masks/780-mask.png
# /kaggle/input/masks/102-mask.png
# /kaggle/input/masks/568-mask.png
# /kaggle/input/masks/791-mask.png
# /kaggle/input/masks/506-mask.png
# /kaggle/input/masks/263-mask.png
# /kaggle/input/masks/570-mask.png
# /kaggle/input/masks/154-mask.png
# /kaggle/input/masks/328-mask.png
# /kaggle/input/masks/137-mask.png
# /kaggle/input/masks/298-mask.png
# /kaggle/input/masks/720-mask.png
# /kaggle/input/masks/68-mask.png
# /kaggle/input/masks/509-mask.png
# /kaggle/input/masks/0-mask.png
# /kaggle/input/masks/635-mask.png
# /kaggle/input/masks/351-mask.png
# /kaggle/input/masks/519-mask.png
# /kaggle/input/masks/11-mask.png
# /kaggle/input/masks/547-mask.png
# /kaggle/input/masks/290-mask.png
# /kaggle/input/masks/503-mask.png
# /kaggle/input/masks/195-mask.png
# /kaggle/input/masks/300-mask.png
# /kaggle/input/masks/494-mask.png
# /kaggle/input/masks/415-mask.png
# /kaggle/input/masks/57-mask.png
# /kaggle/input/masks/144-mask.png
# /kaggle/input/masks/355-mask.png
# /kaggle/input/masks/610-mask.png
# /kaggle/input/masks/567-mask.png
# /kaggle/input/masks/421-mask.png
# /kaggle/input/masks/649-mask.png
# /kaggle/input/masks/278-mask.png
# /kaggle/input/masks/513-mask.png
# /kaggle/input/masks/543-mask.png
# /kaggle/input/masks/518-mask.png
# /kaggle/input/masks/93-mask.png
# /kaggle/input/masks/619-mask.png
# /kaggle/input/masks/691-mask.png
# /kaggle/input/masks/46-mask.png
# /kaggle/input/masks/309-mask.png
# /kaggle/input/masks/378-mask.png
# /kaggle/input/masks/717-mask.png
# /kaggle/input/masks/3-mask.png
# /kaggle/input/masks/714-mask.png
# /kaggle/input/masks/348-mask.png
# /kaggle/input/masks/683-mask.png
# /kaggle/input/masks/648-mask.png
# /kaggle/input/masks/294-mask.png
# /kaggle/input/masks/326-mask.png
# /kaggle/input/masks/49-mask.png
# /kaggle/input/masks/722-mask.png
# /kaggle/input/masks/492-mask.png
# /kaggle/input/masks/750-mask.png
# /kaggle/input/masks/417-mask.png
# /kaggle/input/masks/469-mask.png
# /kaggle/input/masks/465-mask.png
# /kaggle/input/masks/669-mask.png
# /kaggle/input/masks/731-mask.png
# /kaggle/input/masks/529-mask.png
# /kaggle/input/masks/353-mask.png
# /kaggle/input/masks/489-mask.png
# /kaggle/input/masks/496-mask.png
# /kaggle/input/masks/500-mask.png
# /kaggle/input/masks/520-mask.png
# /kaggle/input/masks/182-mask.png
# /kaggle/input/masks/103-mask.png
# /kaggle/input/masks/564-mask.png
# /kaggle/input/masks/2-mask.png
# /kaggle/input/masks/724-mask.png
# /kaggle/input/masks/491-mask.png
# /kaggle/input/masks/655-mask.png
# /kaggle/input/masks/221-mask.png
# /kaggle/input/masks/504-mask.png
# /kaggle/input/masks/246-mask.png
# /kaggle/input/masks/596-mask.png
# /kaggle/input/masks/755-mask.png
# /kaggle/input/masks/97-mask.png
# /kaggle/input/masks/640-mask.png
# /kaggle/input/masks/129-mask.png
# /kaggle/input/masks/552-mask.png
# /kaggle/input/masks/659-mask.png
# /kaggle/input/masks/682-mask.png
# /kaggle/input/masks/20-mask.png
# /kaggle/input/masks/569-mask.png
# /kaggle/input/masks/244-mask.png
# /kaggle/input/masks/516-mask.png
# /kaggle/input/masks/702-mask.png
# /kaggle/input/masks/424-mask.png
# /kaggle/input/masks/259-mask.png
# /kaggle/input/masks/15-mask.png
# /kaggle/input/masks/592-mask.png
# /kaggle/input/masks/25-mask.png
# /kaggle/input/masks/770-mask.png
# /kaggle/input/masks/641-mask.png
# /kaggle/input/masks/400-mask.png
# /kaggle/input/masks/742-mask.png
# /kaggle/input/masks/104-mask.png
# /kaggle/input/masks/43-mask.png
# /kaggle/input/masks/272-mask.png
# /kaggle/input/masks/551-mask.png
# /kaggle/input/masks/28-mask.png
# /kaggle/input/masks/539-mask.png
# /kaggle/input/masks/517-mask.png
# /kaggle/input/masks/482-mask.png
# /kaggle/input/masks/54-mask.png
# /kaggle/input/masks/602-mask.png
# /kaggle/input/masks/675-mask.png
# /kaggle/input/masks/32-mask.png
# /kaggle/input/masks/340-mask.png
# /kaggle/input/masks/792-mask.png
# /kaggle/input/masks/312-mask.png
# /kaggle/input/masks/712-mask.png
# /kaggle/input/masks/63-mask.png
# /kaggle/input/masks/30-mask.png
# /kaggle/input/masks/65-mask.png
# /kaggle/input/masks/199-mask.png
# /kaggle/input/masks/261-mask.png
# /kaggle/input/masks/206-mask.png
# /kaggle/input/masks/249-mask.png
# /kaggle/input/masks/370-mask.png
# /kaggle/input/masks/33-mask.png
# /kaggle/input/masks/139-mask.png
# /kaggle/input/masks/790-mask.png
# /kaggle/input/masks/184-mask.png
# /kaggle/input/masks/147-mask.png
# /kaggle/input/masks/788-mask.png
# /kaggle/input/masks/763-mask.png
# /kaggle/input/masks/591-mask.png
# /kaggle/input/masks/541-mask.png
# /kaggle/input/masks/582-mask.png
# /kaggle/input/masks/325-mask.png
# /kaggle/input/masks/681-mask.png
# /kaggle/input/masks/425-mask.png
# /kaggle/input/masks/302-mask.png
# /kaggle/input/masks/359-mask.png
# /kaggle/input/masks/453-mask.png
# /kaggle/input/masks/236-mask.png
# /kaggle/input/masks/450-mask.png
# /kaggle/input/masks/654-mask.png
# /kaggle/input/masks/427-mask.png
# /kaggle/input/masks/586-mask.png
# /kaggle/input/masks/679-mask.png
# /kaggle/input/masks/647-mask.png
# /kaggle/input/masks/357-mask.png
# /kaggle/input/masks/127-mask.png
# /kaggle/input/masks/414-mask.png
# /kaggle/input/masks/288-mask.png
# /kaggle/input/masks/794-mask.png
# /kaggle/input/masks/320-mask.png
# /kaggle/input/masks/363-mask.png
# /kaggle/input/masks/241-mask.png
# /kaggle/input/masks/696-mask.png
# /kaggle/input/masks/55-mask.png
# /kaggle/input/masks/521-mask.png
# /kaggle/input/masks/293-mask.png
# /kaggle/input/masks/438-mask.png
# /kaggle/input/masks/185-mask.png
# /kaggle/input/masks/304-mask.png
# /kaggle/input/masks/623-mask.png
# /kaggle/input/masks/589-mask.png
# /kaggle/input/masks/430-mask.png
# /kaggle/input/masks/577-mask.png
# /kaggle/input/masks/502-mask.png
# /kaggle/input/masks/739-mask.png
# /kaggle/input/masks/785-mask.png
# /kaggle/input/masks/299-mask.png
# /kaggle/input/masks/73-mask.png
# /kaggle/input/masks/625-mask.png
# /kaggle/input/masks/211-mask.png
# /kaggle/input/masks/457-mask.png
# /kaggle/input/masks/100-mask.png
# /kaggle/input/masks/663-mask.png
# /kaggle/input/masks/574-mask.png
# /kaggle/input/masks/214-mask.png
# /kaggle/input/masks/715-mask.png
# /kaggle/input/masks/599-mask.png
# /kaggle/input/masks/573-mask.png
# /kaggle/input/masks/151-mask.png
# /kaggle/input/masks/738-mask.png
# /kaggle/input/masks/744-mask.png
# /kaggle/input/masks/81-mask.png
# /kaggle/input/masks/797-mask.png
# /kaggle/input/masks/367-mask.png
# /kaggle/input/masks/708-mask.png
# /kaggle/input/masks/644-mask.png
# /kaggle/input/masks/475-mask.png
# /kaggle/input/masks/155-mask.png
# /kaggle/input/masks/202-mask.png
# /kaggle/input/masks/601-mask.png
# /kaggle/input/masks/600-mask.png
# /kaggle/input/masks/196-mask.png
# /kaggle/input/masks/17-mask.png
# /kaggle/input/masks/242-mask.png
# /kaggle/input/masks/319-mask.png
# /kaggle/input/masks/455-mask.png
# /kaggle/input/masks/466-mask.png
# /kaggle/input/masks/86-mask.png
# /kaggle/input/masks/590-mask.png
# /kaggle/input/masks/671-mask.png
# /kaggle/input/masks/605-mask.png
# /kaggle/input/masks/106-mask.png
# /kaggle/input/masks/186-mask.png
# /kaggle/input/masks/9-mask.png
# /kaggle/input/masks/252-mask.png
# /kaggle/input/masks/305-mask.png
# /kaggle/input/masks/109-mask.png
# /kaggle/input/masks/490-mask.png
# /kaggle/input/masks/548-mask.png
# /kaggle/input/masks/617-mask.png
# /kaggle/input/masks/44-mask.png
# /kaggle/input/masks/413-mask.png
# /kaggle/input/masks/401-mask.png
# /kaggle/input/masks/554-mask.png
# /kaggle/input/masks/230-mask.png
# /kaggle/input/masks/166-mask.png
# /kaggle/input/masks/160-mask.png
# /kaggle/input/masks/207-mask.png
# /kaggle/input/masks/209-mask.png
# /kaggle/input/masks/419-mask.png
# /kaggle/input/masks/156-mask.png
# /kaggle/input/masks/662-mask.png
# /kaggle/input/masks/579-mask.png
# /kaggle/input/masks/382-mask.png
# /kaggle/input/masks/505-mask.png
# /kaggle/input/masks/698-mask.png
# /kaggle/input/masks/595-mask.png
# /kaggle/input/masks/75-mask.png
# /kaggle/input/masks/432-mask.png
# /kaggle/input/masks/699-mask.png
# /kaggle/input/masks/224-mask.png
# /kaggle/input/masks/271-mask.png
# /kaggle/input/masks/764-mask.png
# /kaggle/input/masks/405-mask.png
# /kaggle/input/masks/643-mask.png
# /kaggle/input/masks/690-mask.png
# /kaggle/input/masks/164-mask.png
# /kaggle/input/masks/82-mask.png
# /kaggle/input/masks/306-mask.png
# /kaggle/input/masks/603-mask.png
# /kaggle/input/masks/307-mask.png
# /kaggle/input/masks/50-mask.png
# /kaggle/input/masks/756-mask.png
# /kaggle/input/masks/537-mask.png
# /kaggle/input/masks/162-mask.png
# /kaggle/input/masks/773-mask.png
# /kaggle/input/masks/478-mask.png
# /kaggle/input/masks/190-mask.png
# /kaggle/input/masks/757-mask.png
# /kaggle/input/masks/772-mask.png
# /kaggle/input/masks/608-mask.png
# /kaggle/input/masks/526-mask.png
# /kaggle/input/masks/467-mask.png
# /kaggle/input/masks/358-mask.png
# /kaggle/input/masks/689-mask.png
# /kaggle/input/masks/507-mask.png
# /kaggle/input/masks/258-mask.png
# /kaggle/input/masks/92-mask.png
# /kaggle/input/masks/125-mask.png
# /kaggle/input/masks/431-mask.png
# /kaggle/input/masks/468-mask.png
# /kaggle/input/masks/53-mask.png
# /kaggle/input/masks/576-mask.png
# /kaggle/input/masks/546-mask.png
# /kaggle/input/masks/342-mask.png
# /kaggle/input/masks/412-mask.png
# /kaggle/input/masks/781-mask.png
# /kaggle/input/masks/730-mask.png
# /kaggle/input/masks/533-mask.png
# /kaggle/input/masks/255-mask.png
# /kaggle/input/masks/177-mask.png
# /kaggle/input/masks/394-mask.png
# /kaggle/input/masks/540-mask.png
# /kaggle/input/masks/532-mask.png
# /kaggle/input/masks/373-mask.png
# /kaggle/input/masks/572-mask.png
# /kaggle/input/masks/217-mask.png
# /kaggle/input/masks/484-mask.png
# /kaggle/input/masks/316-mask.png
# /kaggle/input/masks/531-mask.png
# /kaggle/input/masks/493-mask.png
# /kaggle/input/masks/729-mask.png
# /kaggle/input/masks/47-mask.png
# /kaggle/input/masks/251-mask.png
# /kaggle/input/masks/713-mask.png
# /kaggle/input/masks/375-mask.png
# /kaggle/input/masks/61-mask.png
# /kaggle/input/masks/6-mask.png
# /kaggle/input/masks/616-mask.png
# /kaggle/input/masks/295-mask.png
# /kaggle/input/masks/1-mask.png
# /kaggle/input/masks/597-mask.png
# /kaggle/input/masks/665-mask.png
# /kaggle/input/masks/487-mask.png
# /kaggle/input/masks/277-mask.png
# /kaggle/input/masks/439-mask.png
# /kaggle/input/masks/121-mask.png
# /kaggle/input/masks/709-mask.png
# /kaggle/input/masks/642-mask.png
# /kaggle/input/masks/760-mask.png
# /kaggle/input/masks/334-mask.png
# /kaggle/input/masks/95-mask.png
# /kaggle/input/masks/333-mask.png
# /kaggle/input/masks/385-mask.png
# /kaggle/input/masks/59-mask.png
# /kaggle/input/masks/587-mask.png
# /kaggle/input/masks/311-mask.png
# /kaggle/input/masks/237-mask.png
# /kaggle/input/masks/161-mask.png
# /kaggle/input/masks/260-mask.png
# /kaggle/input/masks/606-mask.png
# /kaggle/input/masks/666-mask.png
# /kaggle/input/masks/152-mask.png

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, Concatenate
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import KFold
import os
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# **U-Net**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Precision, Recall
import tensorflow as tf
from tensorflow.keras import backend as K

# %%
# Set dataset paths
image_dir = "/kaggle/input/images"
mask_dir = "/kaggle/input/masks"

def load_dataset(image_dir, mask_dir, img_size=(256, 256)):
    images, masks = [], []

    # Extract available mask filenames without "-mask"
    mask_files = {filename.split('-mask')[0]: filename for filename in os.listdir(mask_dir)}

    matched_count = 0
    for filename in os.listdir(image_dir):
        base_name = filename.split('.')[0]  # Extract base name
        
        if base_name in mask_files:  # Only keep images that have masks
            img_path = os.path.join(image_dir, filename)
            mask_path = os.path.join(mask_dir, mask_files[base_name])

            img = load_img(img_path, target_size=img_size, color_mode='grayscale')
            mask = load_img(mask_path, target_size=img_size, color_mode='grayscale')

            images.append(img_to_array(img) / 255.0)
            masks.append(img_to_array(mask) / 255.0)
            matched_count += 1
        else:
            print(f"Skipping {filename}: No corresponding mask found.")

    print(f"Total images with masks loaded: {matched_count}")
    return np.array(images).reshape(-1, 256, 256, 1), np.array(masks).reshape(-1, 256, 256, 1)
 
# Load images and masks
X, Y = load_dataset(image_dir, mask_dir)
# Out:
# Skipping 94.png: No corresponding mask found.
# Skipping 771.png: No corresponding mask found.
# Skipping 761.png: No corresponding mask found.
# Skipping 403.png: No corresponding mask found.
# Skipping 35.png: No corresponding mask found.
# Skipping 628.png: No corresponding mask found.
# Skipping 441.png: No corresponding mask found.
# Skipping 296.png: No corresponding mask found.
# Skipping 538.png: No corresponding mask found.
# Skipping 89.png: No corresponding mask found.
# Skipping 411.png: No corresponding mask found.
# Skipping 281.png: No corresponding mask found.
# Skipping 362.png: No corresponding mask found.
# Skipping 660.png: No corresponding mask found.
# Skipping 256.png: No corresponding mask found.
# Skipping 4.png: No corresponding mask found.
# Skipping 588.png: No corresponding mask found.
# Skipping 229.png: No corresponding mask found.
# Skipping 331.png: No corresponding mask found.
# Skipping 575.png: No corresponding mask found.
# Skipping 673.png: No corresponding mask found.
# Skipping 658.png: No corresponding mask found.
# Skipping 168.png: No corresponding mask found.
# Skipping 578.png: No corresponding mask found.
# Skipping 488.png: No corresponding mask found.
# Skipping 775.png: No corresponding mask found.
# Skipping 150.png: No corresponding mask found.
# Skipping 674.png: No corresponding mask found.
# Skipping 434.png: No corresponding mask found.
# Skipping 371.png: No corresponding mask found.
# Skipping 798.png: No corresponding mask found.
# Skipping 701.png: No corresponding mask found.
# Skipping 458.png: No corresponding mask found.
# Skipping 386.png: No corresponding mask found.
# Skipping 372.png: No corresponding mask found.
# Skipping 614.png: No corresponding mask found.
# Skipping 38.png: No corresponding mask found.
# Skipping 530.png: No corresponding mask found.
# Skipping 223.png: No corresponding mask found.
# Skipping 10.png: No corresponding mask found.
# Skipping 598.png: No corresponding mask found.
# Skipping 36.png: No corresponding mask found.
# Skipping 208.png: No corresponding mask found.
# Skipping 392.png: No corresponding mask found.
# Skipping 639.png: No corresponding mask found.
# Skipping 734.png: No corresponding mask found.
# Skipping 276.png: No corresponding mask found.
# Skipping 356.png: No corresponding mask found.
# Skipping 354.png: No corresponding mask found.
# Skipping 745.png: No corresponding mask found.
# Skipping 264.png: No corresponding mask found.
# Skipping 219.png: No corresponding mask found.
# Skipping 782.png: No corresponding mask found.
# Skipping 758.png: No corresponding mask found.
# Skipping 799.png: No corresponding mask found.
# Skipping 476.png: No corresponding mask found.
# Skipping 447.png: No corresponding mask found.
# Skipping 563.png: No corresponding mask found.
# Skipping 612.png: No corresponding mask found.
# Skipping 337.png: No corresponding mask found.
# Skipping 69.png: No corresponding mask found.
# Skipping 637.png: No corresponding mask found.
# Skipping 776.png: No corresponding mask found.
# Skipping 638.png: No corresponding mask found.
# Skipping 632.png: No corresponding mask found.
# Skipping 361.png: No corresponding mask found.
# Skipping 630.png: No corresponding mask found.
# Skipping 323.png: No corresponding mask found.
# Skipping 118.png: No corresponding mask found.
# Skipping 670.png: No corresponding mask found.
# Skipping 486.png: No corresponding mask found.
# Skipping 179.png: No corresponding mask found.
# Skipping 178.png: No corresponding mask found.
# Skipping 64.png: No corresponding mask found.
# Skipping 8.png: No corresponding mask found.
# Skipping 45.png: No corresponding mask found.
# Skipping 158.png: No corresponding mask found.
# Skipping 87.png: No corresponding mask found.
# Skipping 686.png: No corresponding mask found.
# Skipping 618.png: No corresponding mask found.
# Skipping 442.png: No corresponding mask found.
# Skipping 454.png: No corresponding mask found.
# Skipping 711.png: No corresponding mask found.
# Skipping 84.png: No corresponding mask found.
# Skipping 210.png: No corresponding mask found.
# Skipping 234.png: No corresponding mask found.
# Skipping 365.png: No corresponding mask found.
# Skipping 273.png: No corresponding mask found.
# Skipping 789.png: No corresponding mask found.
# Skipping 557.png: No corresponding mask found.
# Skipping 341.png: No corresponding mask found.
# Skipping 62.png: No corresponding mask found.
# Skipping 110.png: No corresponding mask found.
# Skipping 257.png: No corresponding mask found.
# Skipping 477.png: No corresponding mask found.
# Skipping 175.png: No corresponding mask found.
# Total images with masks loaded: 704

# %%
# Assuming X and Y are your complete dataset arrays
X = np.array(X)
Y = np.array(Y)

# Split into train+val and test sets first (80% train+val, 20% test)
X_train_val, X_test, y_train_val, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Then split train_val into train and validation (75% train, 25% val of the 80% = 60% train, 20% val)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42)

print(f"Training set shape: {X_train.shape}")
print(f"Validation set shape: {X_val.shape}")
print(f"Test set shape: {X_test.shape}")
# Out:
# Training set shape: (422, 256, 256, 1)
# Validation set shape: (141, 256, 256, 1)
# Test set shape: (141, 256, 256, 1)

# %%
# Define custom metrics
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def iou(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
    return K.mean((intersection + smooth) / (union + smooth), axis=0)

# %%
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate
from tensorflow.keras.models import Model
import numpy as np

def unet_model(input_size=(256, 256, 1)):
    inputs = Input(input_size)
    
    # Encoder
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
    
    # Bottleneck
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    
    # Decoder
    u1 = UpSampling2D((2, 2))(c4)
    u1 = Concatenate()([u1, c3])
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(u1)
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(c5)
    
    u2 = UpSampling2D((2, 2))(c5)
    u2 = Concatenate()([u2, c2])
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(u2)
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(c6)
    
    u3 = UpSampling2D((2, 2))(c6)
    u3 = Concatenate()([u3, c1])
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(u3)
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(c7)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c7)
    
    model = Model(inputs, outputs)
    
    model.compile(optimizer='adam', 
                  loss='binary_crossentropy', 
                  metrics=['accuracy', 
                           Precision(name='precision'),
                           Recall(name='recall'),
                           dice_coef,
                           iou])
    return model

# %%
# Build the model
model = unet_model()

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

# Train the model
history = model.fit(X_train, y_train,
                    validation_data=(X_val, y_val),
                    epochs=20,
                    batch_size=8,
                    callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/20
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.7505 - dice_coef: 0.2829 - iou: 0.1659 - loss: 0.9157 - precision: 0.1206 - recall: 0.0018
# E0000 00:00:1744469907.719680      79 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1744469907.953245      79 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - accuracy: 0.7503 - dice_coef: 0.2842 - iou: 0.1668 - loss: 0.9050 - precision: 0.1206 - recall: 0.0017 - val_accuracy: 0.7480 - val_dice_coef: 0.4330 - val_iou: 0.2745 - val_loss: 0.3940 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.7628 - dice_coef: 0.3918 - iou: 0.2442 - loss: 0.4483 - precision: 0.3850 - recall: 0.0554 - val_accuracy: 0.8899 - val_dice_coef: 0.5192 - val_iou: 0.3485 - val_loss: 0.3487 - val_precision: 0.9386 - val_recall: 0.6023 - learning_rate: 0.0010
# Epoch 3/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9103 - dice_coef: 0.6782 - iou: 0.5141 - loss: 0.2637 - precision: 0.8808 - recall: 0.7482 - val_accuracy: 0.9377 - val_dice_coef: 0.7895 - val_iou: 0.6468 - val_loss: 0.1718 - val_precision: 0.9476 - val_recall: 0.7969 - learning_rate: 0.0010
# Epoch 4/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 407ms/step - accuracy: 0.9469 - dice_coef: 0.8338 - iou: 0.7088 - loss: 0.1450 - precision: 0.9212 - recall: 0.8638 - val_accuracy: 0.9548 - val_dice_coef: 0.8693 - val_iou: 0.7662 - val_loss: 0.1267 - val_precision: 0.9592 - val_recall: 0.8569 - learning_rate: 0.0010
# Epoch 5/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 409ms/step - accuracy: 0.9616 - dice_coef: 0.8825 - iou: 0.7833 - loss: 0.1048 - precision: 0.9394 - recall: 0.9055 - val_accuracy: 0.9653 - val_dice_coef: 0.8966 - val_iou: 0.8105 - val_loss: 0.1009 - val_precision: 0.9598 - val_recall: 0.9002 - learning_rate: 0.0010
# Epoch 6/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9696 - dice_coef: 0.9080 - iou: 0.8278 - loss: 0.0839 - precision: 0.9504 - recall: 0.9280 - val_accuracy: 0.9718 - val_dice_coef: 0.9193 - val_iou: 0.8487 - val_loss: 0.0796 - val_precision: 0.9460 - val_recall: 0.9419 - learning_rate: 0.0010
# Epoch 7/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9724 - dice_coef: 0.9202 - iou: 0.8496 - loss: 0.0750 - precision: 0.9522 - recall: 0.9405 - val_accuracy: 0.9697 - val_dice_coef: 0.9202 - val_iou: 0.8513 - val_loss: 0.0906 - val_precision: 0.9741 - val_recall: 0.9039 - learning_rate: 0.0010
# Epoch 8/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9746 - dice_coef: 0.9247 - iou: 0.8570 - loss: 0.0684 - precision: 0.9597 - recall: 0.9395 - val_accuracy: 0.9749 - val_dice_coef: 0.9255 - val_iou: 0.8594 - val_loss: 0.0708 - val_precision: 0.9579 - val_recall: 0.9418 - learning_rate: 0.0010
# Epoch 9/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.9752 - dice_coef: 0.9245 - iou: 0.8566 - loss: 0.0671 - precision: 0.9595 - recall: 0.9418 - val_accuracy: 0.9757 - val_dice_coef: 0.9341 - val_iou: 0.8752 - val_loss: 0.0711 - val_precision: 0.9598 - val_recall: 0.9430 - learning_rate: 0.0010
# Epoch 10/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9776 - dice_coef: 0.9326 - iou: 0.8716 - loss: 0.0604 - precision: 0.9618 - recall: 0.9487 - val_accuracy: 0.9752 - val_dice_coef: 0.9266 - val_iou: 0.8613 - val_loss: 0.0696 - val_precision: 0.9554 - val_recall: 0.9458 - learning_rate: 0.0010
# Epoch 11/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9774 - dice_coef: 0.9317 - iou: 0.8694 - loss: 0.0603 - precision: 0.9628 - recall: 0.9476 - val_accuracy: 0.9774 - val_dice_coef: 0.9350 - val_iou: 0.8767 - val_loss: 0.0642 - val_precision: 0.9592 - val_recall: 0.9509 - learning_rate: 0.0010
# Epoch 12/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9770 - dice_coef: 0.9318 - iou: 0.8702 - loss: 0.0621 - precision: 0.9630 - recall: 0.9454 - val_accuracy: 0.9779 - val_dice_coef: 0.9374 - val_iou: 0.8815 - val_loss: 0.0629 - val_precision: 0.9721 - val_recall: 0.9393 - learning_rate: 0.0010
# Epoch 13/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 409ms/step - accuracy: 0.9798 - dice_coef: 0.9392 - iou: 0.8832 - loss: 0.0546 - precision: 0.9692 - recall: 0.9509 - val_accuracy: 0.9772 - val_dice_coef: 0.9396 - val_iou: 0.8852 - val_loss: 0.0670 - val_precision: 0.9554 - val_recall: 0.9540 - learning_rate: 0.0010
# Epoch 14/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9808 - dice_coef: 0.9431 - iou: 0.8903 - loss: 0.0507 - precision: 0.9669 - recall: 0.9577 - val_accuracy: 0.9778 - val_dice_coef: 0.9359 - val_iou: 0.8787 - val_loss: 0.0637 - val_precision: 0.9705 - val_recall: 0.9407 - learning_rate: 0.0010
# Epoch 15/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9803 - dice_coef: 0.9401 - iou: 0.8857 - loss: 0.0527 - precision: 0.9691 - recall: 0.9515
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 408ms/step - accuracy: 0.9803 - dice_coef: 0.9401 - iou: 0.8858 - loss: 0.0527 - precision: 0.9691 - recall: 0.9516 - val_accuracy: 0.9779 - val_dice_coef: 0.9365 - val_iou: 0.8802 - val_loss: 0.0649 - val_precision: 0.9766 - val_recall: 0.9346 - learning_rate: 0.0010
# Epoch 16/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 409ms/step - accuracy: 0.9813 - dice_coef: 0.9440 - iou: 0.8928 - loss: 0.0482 - precision: 0.9716 - recall: 0.9537 - val_accuracy: 0.9793 - val_dice_coef: 0.9412 - val_iou: 0.8879 - val_loss: 0.0593 - val_precision: 0.9661 - val_recall: 0.9513 - learning_rate: 5.0000e-04
# Epoch 17/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 409ms/step - accuracy: 0.9824 - dice_coef: 0.9481 - iou: 0.8996 - loss: 0.0453 - precision: 0.9730 - recall: 0.9577 - val_accuracy: 0.9794 - val_dice_coef: 0.9447 - val_iou: 0.8947 - val_loss: 0.0610 - val_precision: 0.9663 - val_recall: 0.9515 - learning_rate: 5.0000e-04
# Epoch 18/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 409ms/step - accuracy: 0.9809 - dice_coef: 0.9453 - iou: 0.8950 - loss: 0.0494 - precision: 0.9696 - recall: 0.9553 - val_accuracy: 0.9797 - val_dice_coef: 0.9428 - val_iou: 0.8913 - val_loss: 0.0606 - val_precision: 0.9675 - val_recall: 0.9513 - learning_rate: 5.0000e-04
# Epoch 19/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9831 - dice_coef: 0.9491 - iou: 0.9016 - loss: 0.0432 - precision: 0.9728 - recall: 0.9601
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 409ms/step - accuracy: 0.9831 - dice_coef: 0.9491 - iou: 0.9015 - loss: 0.0432 - precision: 0.9727 - recall: 0.9601 - val_accuracy: 0.9792 - val_dice_coef: 0.9404 - val_iou: 0.8867 - val_loss: 0.0605 - val_precision: 0.9610 - val_recall: 0.9561 - learning_rate: 5.0000e-04
# Epoch 20/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9834 - dice_coef: 0.9498 - iou: 0.9032 - loss: 0.0424 - precision: 0.9722 - recall: 0.9618 - val_accuracy: 0.9798 - val_dice_coef: 0.9455 - val_iou: 0.8964 - val_loss: 0.0610 - val_precision: 0.9728 - val_recall: 0.9464 - learning_rate: 2.5000e-04

# %%
model.summary()
# Out:
# Model: "functional_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_15            │ (None, 256, 256, 1)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_225 (Conv2D)       │ (None, 256, 256, 64)   │            640 │ input_layer_15[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_226 (Conv2D)       │ (None, 256, 256, 64)   │         36,928 │ conv2d_225[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_45          │ (None, 128, 128, 64)   │              0 │ conv2d_226[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_227 (Conv2D)       │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d_45[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_228 (Conv2D)       │ (None, 128, 128, 128)  │        147,584 │ conv2d_227[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_46          │ (None, 64, 64, 128)    │              0 │ conv2d_228[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_229 (Conv2D)       │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_46[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_230 (Conv2D)       │ (None, 64, 64, 256)    │        590,080 │ conv2d_229[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_47          │ (None, 32, 32, 256)    │              0 │ conv2d_230[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_231 (Conv2D)       │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_47[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_232 (Conv2D)       │ (None, 32, 32, 512)    │      2,359,808 │ conv2d_231[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d             │ (None, 64, 64, 512)    │              0 │ conv2d_232[0][0]       │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_45            │ (None, 64, 64, 768)    │              0 │ up_sampling2d[0][0],   │
# │ (Concatenate)             │                        │                │ conv2d_230[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_233 (Conv2D)       │ (None, 64, 64, 256)    │      1,769,728 │ concatenate_45[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_234 (Conv2D)       │ (None, 64, 64, 256)    │        590,080 │ conv2d_233[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_1           │ (None, 128, 128, 256)  │              0 │ conv2d_234[0][0]       │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_46            │ (None, 128, 128, 384)  │              0 │ up_sampling2d_1[0][0], │
# │ (Concatenate)             │                        │                │ conv2d_228[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_235 (Conv2D)       │ (None, 128, 128, 128)  │        442,496 │ concatenate_46[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_236 (Conv2D)       │ (None, 128, 128, 128)  │        147,584 │ conv2d_235[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_2           │ (None, 256, 256, 128)  │              0 │ conv2d_236[0][0]       │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_47            │ (None, 256, 256, 192)  │              0 │ up_sampling2d_2[0][0], │
# │ (Concatenate)             │                        │                │ conv2d_226[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_237 (Conv2D)       │ (None, 256, 256, 64)   │        110,656 │ concatenate_47[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_238 (Conv2D)       │ (None, 256, 256, 64)   │         36,928 │ conv2d_237[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_239 (Conv2D)       │ (None, 256, 256, 1)    │             65 │ conv2d_238[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 23,345,285 (89.06 MB)
#  Trainable params: 7,781,761 (29.69 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 15,563,524 (59.37 MB)

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, accuracy_score
from tensorflow.keras.metrics import MeanIoU

# Evaluate on test set
test_results = model.evaluate(X_test, y_test, verbose=0)
test_metrics = dict(zip(model.metrics_names, test_results))

# Get predictions (probabilities)
y_pred_probs = model.predict(X_test, verbose=0)

# Convert to binary predictions (threshold = 0.5)
y_pred = (y_pred_probs > 0.5).astype(np.uint8)

# Flatten arrays for scikit-learn metrics
y_true_flat = y_test.flatten()
y_pred_flat = y_pred.flatten()

# Calculate additional metrics
test_metrics['sklearn_accuracy'] = accuracy_score(y_true_flat, y_pred_flat)
test_metrics['sklearn_precision'] = precision_score(y_true_flat, y_pred_flat)
test_metrics['sklearn_recall'] = recall_score(y_true_flat, y_pred_flat)

# Calculate IoU
iou = MeanIoU(num_classes=2)
iou.update_state(y_test, y_pred)
test_metrics['mean_iou'] = iou.result().numpy()

# Calculate Dice Coefficient manually
intersection = np.sum(y_true_flat * y_pred_flat)
test_metrics['dice_coef'] = (2. * intersection) / (np.sum(y_true_flat) + np.sum(y_pred_flat))

# Print all metrics in a nice format
print("\n╔══════════════════════════════════════╗")
print("║          Test Set Metrics           ║")
print("╠══════════════════════════╦══════════╣")
print("║ Metric                   ║ Value    ║")
print("╠══════════════════════════╬══════════╣")
for metric, value in test_metrics.items():
    if metric.startswith('val_'):  # Skip validation metrics if present
        continue
    metric_name = metric.replace('_', ' ').title()
    print(f"║ {metric_name:<25} ║ {value:.4f} ║")
print("╚══════════════════════════╩══════════╝")

# Print interpretations
print("\nMetric Interpretations:")
print(f"- Loss: {test_metrics.get('loss', 'N/A'):.4f} (lower is better)")
print(f"- Accuracy: {test_metrics.get('accuracy', test_metrics.get('sklearn_accuracy', 'N/A'))*100:.1f}% correct predictions")
print(f"- Precision: {test_metrics.get('precision', test_metrics.get('sklearn_precision', 'N/A'))*100:.1f}% of positive predictions were correct")
print(f"- Recall: {test_metrics.get('recall', test_metrics.get('sklearn_recall', 'N/A'))*100:.1f}% of actual positives were detected")
print(f"- Dice Coefficient: {test_metrics.get('dice_coef', 'N/A')*100:.1f}% overlap between predictions and ground truth")
print(f"- IoU: {test_metrics.get('iou', test_metrics.get('mean_iou', 'N/A'))*100:.1f}% intersection over union")
# Out:
# ╔══════════════════════════════════════╗
# ║          Test Set Metrics           ║
# ╠══════════════════════════╦══════════╣
# ║ Metric                   ║ Value    ║
# ╠══════════════════════════╬══════════╣
# ║ Loss                      ║ 0.0623 ║
# ║ Compile Metrics           ║ 0.9779 ║
# ║ Sklearn Accuracy          ║ 0.9779 ║
# ║ Sklearn Precision         ║ 0.9650 ║
# ║ Sklearn Recall            ║ 0.9469 ║
# ║ Mean Iou                  ║ 0.9432 ║
# ║ Dice Coef                 ║ 0.9559 ║
# ╚══════════════════════════╩══════════╝
#
# Metric Interpretations:
# - Loss: 0.0623 (lower is better)
# - Accuracy: 97.8% correct predictions
# - Precision: 96.5% of positive predictions were correct
# - Recall: 94.7% of actual positives were detected
# - Dice Coefficient: 95.6% overlap between predictions and ground truth
# - IoU: 94.3% intersection over union

# %%
# Plot training history
def plot_history(history):
    metrics = ['loss', 'accuracy', 'precision', 'recall', 'dice_coef', 'iou']
    
    plt.figure(figsize=(16, 16))
    
    for i, metric in enumerate(metrics):
        plt.subplot(3, 2, i+1)
        plt.plot(history.history[metric], label=f'Train {metric}')
        plt.plot(history.history[f'val_{metric}'], label=f'Validation {metric}')
        plt.title(f'Model {metric}')
        plt.ylabel(metric)
        plt.xlabel('Epoch')
        plt.legend()
    
    plt.tight_layout()
    plt.show()

plot_history(history)

# %%
# Print final results
def print_metrics(metrics_dict, title):
    print(f"\n{title}:")
    for metric, value in metrics_dict.items():
        if isinstance(value, (list, np.ndarray)):
            value = value[-1]  # Get last epoch value
        print(f"{metric}: {value:.4f}")

# Training results (from last epoch)
train_metrics = {metric: history.history[metric][-1] 
                 for metric in history.history 
                 if not metric.startswith('val_')}
print_metrics(train_metrics, "Final Training Results")

# Validation results (from last epoch)
val_metrics = {metric[4:]: history.history[metric][-1] 
               for metric in history.history 
               if metric.startswith('val_')}
print_metrics(val_metrics, "Final Validation Results")

# Test results
print_metrics(test_metrics, "Test Set Results")
# Out:
# Final Training Results:
# accuracy: 0.9833
# dice_coef: 0.9501
# iou: 0.9036
# loss: 0.0428
# precision: 0.9727
# recall: 0.9613
# learning_rate: 0.0003
#
# Final Validation Results:
# accuracy: 0.9798
# dice_coef: 0.9455
# iou: 0.8964
# loss: 0.0610
# precision: 0.9728
# recall: 0.9464
#
# Test Set Results:
# loss: 0.0623
# compile_metrics: 0.9779

# %%
# Visualization of predictions on test samples
# Select 5 random indices from the test dataset
random_indices = np.random.choice(len(X_test), 5, replace=False)

# Generate predictions for the selected test samples
pred = model.predict(X_test[random_indices])

print("\nShowing X-ray, Ground Truth Mask, Predicted Mask, and Overlap:")
plt.figure(figsize=(16, 10))

for i, idx in enumerate(random_indices):
    # Original X-ray
    plt.subplot(4, 5, i+1)
    plt.imshow(X_test[idx].squeeze(), cmap='gray')
    plt.title("X-ray")
    plt.axis('off')

    # Ground Truth Mask
    plt.subplot(4, 5, i+6)
    plt.imshow(y_test[idx].squeeze(), cmap='gray')
    plt.title("Ground Truth Mask")
    plt.axis('off')

    # Predicted Mask
    plt.subplot(4, 5, i+11)
    plt.imshow(pred[i].squeeze(), cmap='gray')
    plt.title("Predicted Mask")
    plt.axis('off')

    # Overlap Visualization
    plt.subplot(4, 5, i+16)
    
    y_true = y_test[idx].squeeze()
    y_pred = (pred[i].squeeze() > 0.5).astype(np.uint8)  # Convert to binary mask

    # Create color-coded overlay
    overlap = np.zeros((y_true.shape[0], y_true.shape[1], 3))  # RGB image
    overlap[y_true == 1] = [0, 0, 1]  # Blue = Ground Truth
    overlap[y_pred == 1] = [1, 0, 0]  # Red = Prediction
    overlap[(y_true == 1) & (y_pred == 1)] = [1, 1, 1]  # White = Correct Segmentation

    plt.imshow(overlap)
    plt.title("Overlap (Blue=GT, Red=Pred, White=Correct)")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# Showing X-ray, Ground Truth Mask, Predicted Mask, and Overlap:
